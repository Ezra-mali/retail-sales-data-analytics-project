# %% [markdown]
# ## Data Source
#
# The dataset used in this project is the "Sample - Superstore" retail dataset obtained from Kaggle.
#
# This dataset contains transaction-level retail sales records from 2014 to 2017, including product categories, customer segments, regional data, sales revenue, quantity, discount, and profit metrics.
#
# The dataset was selected because it aligns with the defined data requirements and supports descriptive, diagnostic, predictive, and prescriptive analytics.

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/Sample - Superstore.csv", encoding="latin1")
df.head()

# %%
df.shape
df.info()
df.describe()
